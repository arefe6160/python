# %%
import requests

# %%
def get_exchange_rate(base_currency, target_currency):
    url = f"https://api.exchangerate-api.com/v4/latest/{base_currency}"
    response = requests.get(url)
    return response.json()['rates'][target_currency]

# %%
def convert_currency(amount, exchange_rate):
    return amount * exchange_rate

# %%
base_currency = 'USD'
target_currency = 'CAD'
exchange_rate=get_exchange_rate(base_currency,target_currency)
print(exchange_rate)

# %%
usd_amount = 100
cad_amount = cad_amount * exchange_rate
cad_amount
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 usd_amount = 100
# ----> 2 cad_amount = cad_amount * exchange_rate
#       3 cad_amount
#
# NameError: name 'cad_amount' is not defined

# %%
base_currency= "USD"
url = f"https://api.giphy.com/v1/gifs/search{base_currency}"

# %%
# Out:
# 1.36
# 136.0

# %%
# %pip install currencies
# Out:
# Requirement already satisfied: currencies in c:\users\sarayetell\appdata\local\programs\python\python313\lib\site-packages (2020.12.12)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import currencies

# %%
list(currencies.MONEY_FORMATS.keys())
# Out:
# ['AED',
#  'AFN',
#  'ALL',
#  'AMD',
#  'ANG',
#  'AOA',
#  'ARS',
#  'AUD',
#  'AWG',
#  'AZN',
#  'BAM',
#  'BBD',
#  'BDT',
#  'BGN',
#  'BHD',
#  'BND',
#  'BOB',
#  'BRL',
#  'BSD',
#  'BTN',
#  'BWP',
#  'BYR',
#  'BZD',
#  'CAD',
#  'CHF',
#  'CLP',
#  'CNY',
#  'COP',
#  'CRC',
#  'CZK',
#  'DKK',
#  'DOP',
#  'DZD',
#  'EGP',
#  'ETB',
#  'EUR',
#  'FJD',
#  'GBP',
#  'GEL',
#  'GHS',
#  'GMD',
#  'GTQ',
#  'GYD',
#  'HKD',
#  'HNL',
#  'HRK',
#  'HUF',
#  'IDR',
#  'ILS',
#  'INR',
#  'ISK',
#  'JEP',
#  'JMD',
#  'JOD',
#  'JPY',
#  'KES',
#  'KGS',
#  'KHR',
#  'KRW',
#  'KWD',
#  'KYD',
#  'KZT',
#  'LBP',
#  'LKR',
#  'LTL',
#  'LVL',
#  'MAD',
#  'MDL',
#  'MGA',
#  'MKD',
#  'MMK',
#  'MNT',
#  'MOP',
#  'MUR',
#  'MVR',
#  'MXN',
#  'MYR',
#  'MZN',
#  'NAD',
#  'NGN',
#  'NIO',
#  'NOK',
#  'NPR',
#  'NZD',
#  'OMR',
#  'PEN',
#  'PGK',
#  'PHP',
#  'PKR',
#  'PLN',
#  'PYG',
#  'QAR',
#  'RON',
#  'RSD',
#  'RUB',
#  'RWF',
#  'SAR',
#  'SCR',
#  'SEK',
#  'SGD',
#  'STD',
#  'SYP',
#  'THB',
#  'TND',
#  'TRY',
#  'TTD',
#  'TWD',
#  'TZS',
#  'UAH',
#  'UGX',
#  'USD',
#  'UYU',
#  'VEF',
#  'VND',
#  'VUV',
#  'WST',
#  'XAF',
#  'XBT',
#  'XCD',
#  'XOF',
#  'XPF',
#  'ZAR',
#  'ZMW']
