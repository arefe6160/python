# %%
contactbook
metods:
    add contactbook
    read
    update
    delete

# %%
# Out:
# welcome to contact book app
# 1. add
# 2. edit
# 3. view
# 4. delete
# 5. quit
# welcome to contact book app
# 1. add
# 2. edit
# 3. view
# 4. delete
# 5. quit
# name:ali
# phone: 0919
# email:ali
# --------------------------------------------------
# welcome to contact book app
# 1. add
# 2. edit
# 3. view
# 4. delete
# 5. quit
# welcome to contact book app
# 1. add
# 2. edit
# 3. view
# 4. delete
# 5. quit
# name:ali
# phone: 0919
# email:ali
# --------------------------------------------------
# name:reza
# phone: 0912
# email:reza
# --------------------------------------------------
# welcome to contact book app
# 1. add
# 2. edit
# 3. view
# 4. delete
# 5. quit
# welcome to contact book app
# 1. add
# 2. edit
# 3. view
# 4. delete
# 5. quit
# name:ali
# phone: 0945
# email:ali
# --------------------------------------------------
# name:reza
# phone: 0912
# email:reza
# --------------------------------------------------
# welcome to contact book app
# 1. add
# 2. edit
# 3. view
# ...

# %%
book = contactbook()

# %%
book.add(name='reza',email='reza@gmail.com',phone='09192328210')
book.add(name='ali',email='ali@gmail.com',phone='09194319743')

# %%
book.view()
# Out:
# name:reza
# phone: 09192328210
# email:reza@gmail.com
# --------------------------------------------------
# name:ali
# phone: 0936
# email: ali
# --------------------------------------------------

# %%
book.delete('ali')
# Out:
# cantact not found!

# %%
book.update('ali',phone = '0936',email= ' ali')
