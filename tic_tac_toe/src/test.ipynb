# %%
tictactoe
    -__init__
    -get_random_first_player
    -fix_spot: mark board
    -win(self,player)
    -if board filled
    -swap player turn
    -show board

# %%
game = tictactoe()

# %%
game.show()
# Out:
#  | |
# -----
#  | |
# -----
#  | |

# %%
game.start()
# Out:
#  | |
# -----
#  | |
# -----
#  | |
#
#
# Player X turn
#
#
# X| |
# -----
#  | |
# -----
#  | |
#
#
# Player O turn
#
#
# X| |O
# -----
#  | |
# -----
#  | |
#
#
# Player X turn
#
#
# X| |O
# -----
#  |X|
# -----
#  | |
#
#
# Player O turn
# Invalid cell! Try again.
#
#
# X| |O
# -----
#  |X|
# -----
#  | |
#
#
# Player O turn
#
#
# X| |O
# -----
#  |X|O
# -----
#  | |
#
#
# Player X turn
#
#
# X| |O
# -----
#  |X|O
# -----
#  | |X
#
#
# Player X won the game!
